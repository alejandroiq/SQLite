# %% [markdown]
# # Practice for Grouping Data with SQL

# %% [markdown]
# Import the germane libraries and connect to the database.

# %%
# Run this code

import pandas as pd
import sqlite3

conn = sqlite3.connect('data (3).sqlite')
pd.read_sql("""
SELECT *
  FROM products;
""", conn)
# Out:
#     productCode                            productName   productLine  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 105   S700_3505                            The Titanic         Ships
# 106   S700_3962                         The Queen Mary         Ships
# 107   S700_4002              American Airlines: MD-11S        Planes
# 108    S72_1253                       Boeing X-32A JSF        Planes
# 109    S72_3212                             Pont Yacht         Ships
#
#     productScale              productVendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# ...

# %% [markdown]
# 1. Select the product line
# *   Count the number of each product line
# *   Give the count the alias "count"
# *   Sort descending by count

# %%
# Group by: This clause is a MUST with aggreated functions

pd.read_sql("""
SELECT productLine,
        COUNT(*) AS my_count
  FROM products
  GROUP BY productLine
  ORDER BY my_count DESC;
""", conn)
# Out:
#         productLine  my_count
# 0      Classic Cars        38
# 1      Vintage Cars        24
# 2       Motorcycles        13
# 3            Planes        12
# 4  Trucks and Buses        11
# 5             Ships         9
# 6            Trains         3

# %% [markdown]
# 2. Select the product line
# - Determine the average by Price by product line
# - Give the average the alias "avgPrice"
# - Sort descending by avgPrice

# %%
# Group by

pd.read_sql("""
SELECT productLine, AVG(CAST(buyPrice AS INTEGER)) AS avg_buyPrice
  FROM products
  GROUP BY productLine
  ORDER BY avg_buyPrice DESC;
""", conn)
# Out:
#         productLine  avg_buyPrice
# 0      Classic Cars     63.947368
# 1  Trucks and Buses     55.636364
# 2       Motorcycles     50.230769
# 3            Planes     49.250000
# 4             Ships     46.555556
# 5      Vintage Cars     45.583333
# 6            Trains     43.333333

# %% [markdown]
# 3. Select the product line
# - Find the minimum of the MSRP as minMSRP
# - Find the maximum of the MSRP as maxMSRP

# %%
# Group by

pd.read_sql("""
SELECT productLine, MIN(buyPrice) AS min_buyPrice, MAX(buyPrice) AS max_buyPrice
  FROM products
  GROUP BY productLine
""", conn)
# Out:
#         productLine  min_buyPrice  max_buyPrice
# 0      Classic Cars         15.91        103.42
# 1       Motorcycles         24.14         91.02
# 2            Planes         29.34         77.27
# 3             Ships         33.30         82.34
# 4            Trains         26.72         67.56
# 5  Trucks and Buses         24.92         84.76
# 6      Vintage Cars         20.61         86.70

# %% [markdown]
# 4. Repeat (3), but only select the rows where the MSRP is $50 or more.

# %%
# Group by & where

pd.read_sql("""
SELECT productLine, MIN(MSRP) AS min_MSRP, MAX(MSRP) AS max_MSRP
  FROM products
  WHERE MSRP >= 50
  GROUP BY productLine
""", conn)
# Out:
#         productLine  min_MSRP  max_MSRP
# 0      Classic Cars     50.31    214.30
# 1       Motorcycles     60.57    193.66
# 2            Planes     68.24    157.69
# 3             Ships     54.60    122.89
# 4            Trains     58.58    100.84
# 5  Trucks and Buses     54.11    136.67
# 6      Vintage Cars     50.31    170.00

# %% [markdown]
# 5. Repeat (2), but only select the product lines with an average price greater than $50.

# %%
# Group by & having

pd.read_sql("""
SELECT productLine, AVG(buyPrice) as avg_buyPrice
  FROM products
  GROUP BY productLine
  HAVING avg_buyPrice >= 50
  ORDER BY avg_buyPrice DESC
""", conn)
# Out:
#         productLine  avg_buyPrice
# 0      Classic Cars     64.446316
# 1  Trucks and Buses     56.329091
# 2       Motorcycles     50.685385

# %% [markdown]
# 6. Select the product line
# - Find the average buy price as 'buyPrice' and the average MSRP as 'avgMSRP'
# - Only select MSRP greater than equal to $50
# - Only select avgPrice greater than equal to $50
# - Group by by product line and order by the ascending average price

# %%
# Group by & where & having

pd.read_sql("""
SELECT productLine, AVG(buyPrice) as avg_buyPrice, AVG(MSRP) as avg_MSRP
  FROM products
  WHERE MSRP >= 50
  GROUP BY productLine
  HAVING avg_MSRP >= 50
  ORDER BY avg_MSRP ASC
""", conn)
# Out:
#         productLine  avg_buyPrice    avg_MSRP
# 0            Trains     43.923333   73.853333
# 1             Ships     47.007778   86.563333
# 2            Planes     51.161818   93.139091
# 3      Vintage Cars     50.680000   96.382000
# 4       Motorcycles     52.897500  101.924167
# 5  Trucks and Buses     56.329091  103.183636
# 6      Classic Cars     67.133611  122.546667

# %%
pd.read_sql("""
SELECT productLine, AVG(buyPrice) AS avgPrice, AVG(MSRP) AS avgMSRP
 FROM products
 WHERE MSRP >= 50
 GROUP BY productLine
 HAVING avgPrice >= 50
 ORDER By avgPrice ASC
""", conn)
# Out:
#         productLine   avgPrice     avgMSRP
# 0      Vintage Cars  50.680000   96.382000
# 1            Planes  51.161818   93.139091
# 2       Motorcycles  52.897500  101.924167
# 3  Trucks and Buses  56.329091  103.183636
# 4      Classic Cars  67.133611  122.546667

# %%
conn.close()
